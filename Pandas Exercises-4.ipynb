# %% [markdown]
# # Pandas Case Study-4

# %% [markdown]
# # Pandas Exercise: Grouping (OCCUPATION FILE)

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %%
url='https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user'
df=pd.read_csv(url,sep='|')
df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step 3. Assign it to a variable called users.

# %%
users=df
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %% [markdown]
# ### Step 4. Discover what is the mean age per occupation

# %%
users.dtypes
# Out:
# user_id        int64
# age            int64
# gender        object
# occupation    object
# zip_code      object
# dtype: object

# %%
users[['occupation','age']].groupby(['occupation']).mean().head()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060

# %% [markdown]
# ### Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
df1=users.loc[(users['gender']=='M')& (users['occupation'])]
df1.head()
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344

# %%
df1[['gender','occupation']].groupby(['occupation']).agg(['max'])
# Out:
#               gender
#                  max
# occupation
# administrator      M
# artist             M
# doctor             M
# educator           M
# engineer           M
# entertainment      M
# executive          M
# healthcare         M
# homemaker          M
# lawyer             M
# librarian          M
# marketing          M
# none               M
# other              M
# programmer         M
# retired            M
# salesman           M
# scientist          M
# student            M
# technician         M
# writer             M

# %% [markdown]
# ### Step 6. For each occupation, calculate the minimum and maximum ages

# %%
users[['occupation','age']].groupby(['occupation']).agg(['min','max']).add_suffix('_age').head()
# Out:
#               age_age
#               min_age max_age
# occupation
# administrator      21      70
# artist             19      48
# doctor             28      64
# educator           23      63
# engineer           22      70

# %% [markdown]
# ### Step 7. For each combination of occupation and gender, calculate the mean age

# %%
users[['occupation','gender','age']].groupby(['occupation','gender']).mean().head()
# Out:
#                             age
# occupation    gender
# administrator F       40.638889
#               M       37.162791
# artist        F       30.307692
#               M       32.333333
# doctor        M       43.571429

# %% [markdown]
# ### Step 8.  For each occupation present the percentage of women and men

# %%
df2=users.loc[(users['gender']=='F') & users['occupation']]
df2.head()
# Out:
#     user_id  age gender occupation zip_code
# 1         2   53      F      other    94043
# 4         5   33      F      other    15213
# 10       11   39      F      other    30329
# 11       12   28      F      other    06405
# 14       15   49      F   educator    97301

# %%
df1.head()
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344

# %%
df2[['gender','occupation']].groupby(['occupation']).agg(['max'])
# Out:
#               gender
#                  max
# occupation
# administrator      F
# artist             F
# educator           F
# engineer           F
# entertainment      F
# executive          F
# healthcare         F
# homemaker          F
# lawyer             F
# librarian          F
# marketing          F
# none               F
# other              F
# programmer         F
# retired            F
# salesman           F
# scientist          F
# student            F
# technician         F
# writer             F
