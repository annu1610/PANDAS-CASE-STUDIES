# %% [markdown]
# # Pandas Case Study -7

# %% [markdown]
# # Pandas Exercise: Basic Stats (Wind Statistics)

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/guipsamora/pandas_exercises/blob/master/Stats/Wind_Stats/wind.data)

# %%
df=pd.read_table('wind.data',sep=' ')
df.head()
# Out:
#    Yr  Mo   Dy  Unnamed: 3  Unnamed: 4    RPT  Unnamed: 6  Unnamed: 7    VAL  \
# 0  61 NaN  1.0         NaN         1.0  15.04       14.96       13.17    NaN
# 1  61 NaN  1.0         NaN         2.0  14.71         NaN         NaN    NaN
# 2  61 NaN  1.0         NaN         3.0  18.50       16.88       12.33  10.13
# 3  61 NaN  1.0         NaN         4.0  10.58         NaN        6.63  11.75
# 4  61 NaN  1.0         NaN         5.0  13.33       13.25       11.42    NaN
#
#    Unnamed: 9  ...  MUL  Unnamed: 30  Unnamed: 31  CLO  Unnamed: 33  \
# 0        9.29  ...  NaN          NaN          NaN  NaN          NaN
# 1       10.83  ...  NaN          NaN          NaN  NaN          NaN
# 2       11.17  ...  NaN          NaN          NaN  NaN          NaN
# 3         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 4        6.17  ...  NaN          NaN          NaN  NaN          NaN
#
#    Unnamed: 34  BEL  Unnamed: 36  Unnamed: 37  MAL
# 0          NaN  NaN          NaN          NaN  NaN
# 1          NaN  NaN          NaN          NaN  NaN
# 2          NaN  NaN          NaN          NaN  NaN
# 3          NaN  NaN          NaN          NaN  NaN
# 4          NaN  NaN          NaN          NaN  NaN
#
# [5 rows x 39 columns]

# %%
df=pd.read_table('wind.data',sep='\s+')
df.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
df.dtypes
# Out:
# Yr       int64
# Mo       int64
# Dy       int64
# RPT    float64
# VAL    float64
# ROS    float64
# KIL    float64
# SHA    float64
# BIR    float64
# DUB    float64
# CLA    float64
# MUL    float64
# CLO    float64
# BEL    float64
# MAL    float64
# dtype: object

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
data=df
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
Date=data['Yr'].astype(str)+'-'+data['Mo'].astype(str)+'-'+data['Dy'].astype(str)

# %%
data['Date']=pd.to_datetime(Date)

# %%
data.drop(columns=['Yr','Mo','Dy'],axis=1,inplace=True)

# %%
data.head()
# Out:
#      RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL    CLO    BEL  \
# 0  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83  12.58  18.50
# 1  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79   9.67  17.54
# 2  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50   7.67  12.75
# 3  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83   5.88   5.46
# 4  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92  10.34  12.92
#
#      MAL       Date
# 0  15.04 2061-01-01
# 1  13.83 2061-01-02
# 2  12.71 2061-01-03
# 3  10.88 2061-01-04
# 4  11.83 2061-01-05

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data.set_index('Date',inplace=True)

# %%
data.head()
# Out:
#               RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# Date
# 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#               CLO    BEL    MAL
# Date
# 2061-01-01  12.58  18.50  15.04
# 2061-01-02   9.67  17.54  13.83
# 2061-01-03   7.67  12.75  12.71
# 2061-01-04   5.88   5.46  10.88
# 2061-01-05  10.34  12.92  11.83

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum(axis=0)
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.notnull().sum()
# Out:
# RPT    6568
# VAL    6571
# ROS    6572
# KIL    6569
# SHA    6572
# BIR    6574
# DUB    6571
# CLA    6572
# MUL    6571
# CLO    6573
# BEL    6574
# MAL    6570
# dtype: int64

# %%
# OR
data.shape[0]-data.isnull().sum()
# Out:
# RPT      6568
# VAL      6571
# ROS      6572
# KIL      6569
# SHA      6572
# BIR      6574
# DUB      6571
# CLA      6572
# MUL      6571
# CLO      6573
# BEL      6574
# MAL      6570
# Date     6574
# Month    6574
# Day      6574
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
data.mean().mean()
# Out:
# 10.227982360836924

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
Loc_stats=pd.DataFrame()
Loc_stats['Min']=data.min()
Loc_stats['Max']=data.max()
Loc_stats['Mean']=data.mean()
Loc_stats['Std']=data.std()

# %%
Loc_stats
# Out:
#       Min    Max       Mean       Std
# RPT  0.67  35.80  12.362987  5.618413
# VAL  0.21  33.37  10.644314  5.267356
# ROS  1.50  33.84  11.660526  5.008450
# KIL  0.00  28.46   6.306468  3.605811
# SHA  0.13  37.54  10.455834  4.936125
# BIR  0.00  26.16   7.092254  3.968683
# DUB  0.00  30.37   9.797343  4.977555
# CLA  0.00  31.08   8.495053  4.499449
# MUL  0.00  25.88   8.493590  4.166872
# CLO  0.04  28.21   8.707332  4.503954
# BEL  0.13  42.38  13.121007  5.835037
# MAL  0.67  42.54  15.599079  6.699794

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
Day_stats=pd.DataFrame()
Day_stats['Min']=data.min(axis=1)
Day_stats['Max']=data.max(axis=1)
Day_stats['Mean']=data.mean(axis=1)
Day_stats['Std']=data.std(axis=1)

# %%
Day_stats.head()
# Out:
#              Min    Max       Mean       Std
# Date
# 2061-01-01  9.29  18.50  13.018182  2.808875
# 2061-01-02  6.50  17.54  11.336364  3.188994
# 2061-01-03  6.17  18.50  11.641818  3.681912
# 2061-01-04  1.79  11.75   6.619167  3.198126
# 2061-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
data.loc[data.index.month==1].mean()
# Out:
# RPT      14.847325
# VAL      12.914560
# ROS      13.299624
# KIL       7.199498
# SHA      11.667734
# BIR       8.054839
# DUB      11.819355
# CLA       9.512047
# MUL       9.543208
# CLO      10.053566
# BEL      14.550520
# MAL      18.028763
# Month     1.000000
# Day      16.000000
# dtype: float64

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
data.loc[(data.index.month==1) & (data.index.day==1)].head()
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 2062-01-01   9.29   3.42  11.54   3.50   2.21   1.96  10.41   2.79   3.54
# 2063-01-01  15.59  13.62  19.79   8.38  12.25  10.00  23.45  15.71  13.59
# 2064-01-01  25.80  22.13  18.21  13.25  21.29  14.79  14.12  19.58  13.25
# 2065-01-01   9.54  11.92   9.00   4.38   6.08   5.21  10.25   6.08   5.71
#
#               CLO    BEL    MAL       Date  Month  Day
# Date
# 2061-01-01  12.58  18.50  15.04 2061-01-01      1    1
# 2062-01-01   5.17   4.38   7.92 2062-01-01      1    1
# 2063-01-01  14.37  17.58  34.13 2063-01-01      1    1
# 2064-01-01  16.75  28.96  21.00 2064-01-01      1    1
# 2065-01-01   8.63  12.04  17.41 2065-01-01      1    1

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
data[data.index.day==1].head()
# Out:
#               RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 2061-01-01  15.04  14.96  13.17  9.29    NaN   9.87  13.67  10.25  10.83
# 2061-02-01  14.25  15.12   9.04  5.88  12.08   7.17  10.17   3.63   6.50
# 2061-03-01  12.67  13.13  11.79  6.42   9.79   8.54  10.25  13.29    NaN
# 2061-04-01   8.38   6.34   8.33  6.75   9.33   9.54  11.67   8.21  11.21
# 2061-05-01  15.87  13.88  15.37  9.79  13.46  10.17   9.96  14.04   9.75
#
#               CLO    BEL    MAL       Date  Month  Day
# Date
# 2061-01-01  12.58  18.50  15.04 2061-01-01      1    1
# 2061-02-01   5.50   9.17   8.00 2061-02-01      2    1
# 2061-03-01  12.21  20.62    NaN 2061-03-01      3    1
# 2061-04-01   6.46  11.96   7.17 2061-04-01      4    1
# 2061-05-01   9.92  18.63  11.12 2061-05-01      5    1

# %% [markdown]
# ### Step 14. Downsample the record to a weekly frequency for each location.

# %%
data[::7].head()
# Out:
#               RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA    MUL  \
# Date
# 2061-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25  10.83
# 2061-01-08  10.96   9.75   7.62   5.91   9.62   7.29  14.29   7.62   9.25
# 2061-01-15  12.04   9.67  11.75   2.37   7.38   3.13   2.50   6.83   4.75
# 2061-01-22   9.59   5.88   9.92   2.17   6.87   5.50   9.38   7.04   6.34
# 2061-01-29    NaN  23.91  22.29  17.54  24.08  19.70  22.00  20.25  21.46
#
#               CLO    BEL    MAL       Date  Month  Day
# Date
# 2061-01-01  12.58  18.50  15.04 2061-01-01      1    1
# 2061-01-08  10.46  16.62  16.46 2061-01-08      1    8
# 2061-01-15   5.63   7.54   6.75 2061-01-15      1   15
# 2061-01-22   7.50  10.88   9.92 2061-01-22      1   22
# 2061-01-29  19.95  27.71  23.38 2061-01-29      1   29

# %% [markdown]
# ### Step 15. Calculate the mean windspeed for each month in the dataset.
# #### Treat January 1961 and January 1962 as *different* months.
# #### (hint: first find a  way to create an identifier unique for each month.)

# %%
data.resample('M').mean().head()
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1969-01-31  12.824839  12.113871  11.403871  6.708710  10.557097  5.926452
# 1969-02-28  13.504643  10.426786  14.240714  7.326786  11.314643  5.482857
# 1969-03-31  10.398710   8.533226  12.277419  6.125161   9.618065  4.942581
# 1969-04-30  12.591333   9.769333  10.828000  6.937333  11.304667  5.578000
# 1969-05-31   9.419032   7.941935   9.298387  5.137097   8.618710  5.391935
#
#                   DUB       CLA       MUL       CLO        BEL        MAL  \
# Date
# 1969-01-31   9.882903  8.375161  8.378065  9.515484  13.410000  16.957742
# 1969-02-28  10.983929  8.747143  8.994286  9.081071  14.334643  19.786786
# 1969-03-31   9.193226  8.503226  8.376129  7.800968  10.394194  16.420000
# 1969-04-30   9.383333  8.141667  9.201333  8.370333  11.905667  14.124000
# 1969-05-31   6.309032  5.752581  5.907419  6.317419   9.332258  11.794839
#
#             Month   Day
# Date
# 1969-01-31    1.0  16.0
# 1969-02-28    2.0  14.5
# 1969-03-31    3.0  16.0
# 1969-04-30    4.0  15.5
# 1969-05-31    5.0  16.0

# %% [markdown]
# ### Step 16. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
week=data.resample('W').agg(['min','max','mean','std'])
week.loc[week.index[1:53],'RPT':'MAL'].head()
# Out:
#              RPT                               VAL                    \
#              min    max       mean       std   min    max       mean
# Date
# 1969-01-12  9.33  22.34  14.708571  5.473684  3.29  18.50  12.521429
# 1969-01-19  4.50  25.08  15.030000  6.915213  1.50  25.17  16.452857
# 1969-01-26  4.00  20.54  14.438571  5.990624  5.13  20.25  14.267143
# 1969-02-02  5.21  18.58  13.510000  5.100791  3.96  19.79  11.917143
# 1969-02-09  5.17  21.50  12.698571  6.207413  1.96  19.00   9.387143
#
#                        ROS           ...           CLO             BEL         \
#                  std   min    max    ...          mean       std   min    max
# Date                                 ...
# 1969-01-12  5.728247  8.46  20.91    ...     10.124286  3.337603  6.04  18.84
# 1969-01-19  7.936619  4.63  17.79    ...      8.385714  4.497150  2.62  19.46
# 1969-01-26  5.881340  4.79  19.21    ...     10.720000  5.260133  3.46  22.04
# 1969-02-02  5.593549  3.83  15.34    ...     10.771429  4.620326  4.83  26.30
# 1969-02-09  7.217457  5.25  19.92    ...      8.560000  3.519029  9.33  24.62
#
#                                    MAL
#                  mean       std    min    max       mean       std
# Date
# 1969-01-12  12.130000  4.967035  10.04  27.71  20.385714  7.104165
# 1969-01-19  13.624286  6.208156   7.62  24.25  14.248571  6.935848
# 1969-01-26  15.475714  6.269439   7.46  19.62  15.827143  4.539177
# 1969-02-02  15.757143  7.294486   9.13  31.54  20.284286  8.084221
# 1969-02-09  16.991429  6.145994  13.08  27.00  19.398571  5.187522
#
# [5 rows x 48 columns]
